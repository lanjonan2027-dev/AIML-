# %%
#basics

#sample data
import matplotlib.pyplot as plt
x = [1,2,4,5,6]
y = [2,7,5,4,3]

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Line PLot')
plt.show()

# %%
#Activity 1
from sklearn.datasets import load_iris
iris = load_iris(as_frame = True)
df = iris.frame
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                5.1               3.5  ...               0.2       0
# 1                4.9               3.0  ...               0.2       0
# 2                4.7               3.2  ...               0.2       0
# 3                4.6               3.1  ...               0.2       0
# 4                5.0               3.6  ...               0.2       0
#
# [5 rows x 5 columns]

# %%
 #Activity 2
 plt.scatter(df['sepal length (cm)'], df['petal length (cm)'])
 plt.xlabel('sepal length')
 plt.ylabel('petal length')
 plt.title('Scatter Plot')
 plt.show()

# %%
#Activity3

plt.hist(df['petal width (cm)'])
plt.title("Distribution")
plt.show();

# %%
#Activity4

species = ['Sentosa', 'Versicolor','Virginica']
count = df['target'].value_counts()
plt.bar(species,count)
plt.show()

# %%
if df_weather is not None:
    # Convert 'time' column to datetime
    df_weather['time'] = pd.to_datetime(df_weather['time'])

    # Extract date from the 'time' column
    df_weather['date'] = df_weather['time'].dt.date

    # Group by date and count entries
    daily_counts = df_weather.groupby('date').size().reset_index(name='record_count')

    print("Number of records per day:")
    display(daily_counts)
else:
    print("df_weather is not loaded. Please load your weather data first.")
# Out:
# Number of records per day:
#          date  record_count
# 0  2026-07-21            24
# 1  2026-07-22            24
# 2  2026-07-23            24
# 3  2026-07-24            24
# 4  2026-07-25            24
# 5  2026-07-26            24
# 6  2026-07-27            24
# 7  2026-07-28            24
